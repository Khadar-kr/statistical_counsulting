# %%
import pandas as pd
data = pd.read_csv('simulation_output.csv')
# Out:
# /var/folders/2_/bhldy0qj4k5dfrybcw8kkm6m0000gn/T/ipykernel_95513/3488584007.py:2: DtypeWarning: Columns (18,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('simulation_output.csv')

# %%
data.head()
# Out:
#                        ReservableOptionMarketGroupId  WeekBeforeArrival  \
# 0      Domestic-Thundurus-Meditite-Mobile-2024-01-01                 52
# 1          DACH-Thundurus-Meditite-Mobile-2024-01-01                 52
# 2       Benelux-Thundurus-Meditite-Mobile-2024-01-01                 52
# 3  Rest of Europe-Thundurus-Meditite-Mobile-2024-...                 52
# 4      Domestic-Thundurus-Meditite-Mobile-2024-01-01                 51
#
#   WeekStartDate MarketGroupCode BrandGroupCode CampsiteCode AccoKindCode  \
# 0    2024-01-01        Domestic      Thundurus     Meditite       Mobile
# 1    2024-01-01            DACH      Thundurus     Meditite       Mobile
# 2    2024-01-01         Benelux      Thundurus     Meditite       Mobile
# 3    2024-01-01  Rest of Europe      Thundurus     Meditite       Mobile
# 4    2024-01-01        Domestic      Thundurus     Meditite       Mobile
#
#   AccoTypeRangeCode   SpecialPeriodCode SeasonalCluster  ... DiscountedPrice  \
# ...
